# %% [markdown]
# **Basic Operations**

# %% [markdown]
# _Illustrating basic Python operations_

# %% [markdown]
# ***

# %% [markdown]
# **Operations Covered:**
# * _Defining variables_
# * _Storing data_
# * _Replacing data_
# * _Concatenating data_

# %%
a = [1, 2, 7]
b = [4, 5, 6]

# %%
print(a[0])
print(b[2])
# Out:
# 1
# 6

# %%
a[2] = 5
print(a)
# Out:
# [1, 2, 5]

# %%
c = ['Joseph', 'Anna', 'Richard']

# %%
print(c)
# Out:
# ['Joseph', 'Anna', 'Richard']

# %%
d = [c, a]

# %%
print(d)
# Out:
# [['Joseph', 'Anna', 'Richard'], [1, 2, 5]]

# %%
e = ['Joseph', 'Anna', 5]

# %%
print(e)
# Out:
# ['Joseph', 'Anna', 5]

# %%
len(e)
# Out:
# 3

# %%
f = a + b

# %%
print(f)
# Out:
# [1, 2, 5, 4, 5, 6]

# %%
f[0:3]
# Out:
# [1, 2, 5]

# %%
f[:3]
# Out:
# [1, 2, 5]

# %%
f[3:]
# Out:
# [4, 5, 6]

# %%
f[:]
# Out:
# [1, 2, 5, 4, 5, 6]

# %%
print(sum(f))
# Out:
# 23

# %% [markdown]
# **Statistical Calculation**

# %% [markdown]
# _Try something new_

# %%
import statistics

# %%
data1 = [1, 2, 3, 4, 5, 2]
print(statistics.mean(data1))
print(statistics.mode(data1))
print(statistics.median(data1))
# Out:
# 2.8333333333333335
# 2
# 2.5

# %%
print(statistics.variance(data1))
print(statistics.stdev(data1))
# Out:
# 2.1666666666666665
# 1.4719601443879744

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()
