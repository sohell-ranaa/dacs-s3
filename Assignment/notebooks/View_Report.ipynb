# %% [markdown]
# # View Markdown Files
# Run cells below to view any `.md` file rendered in browser

# %%
from IPython.display import display, Markdown

# View REPORT.md
display(Markdown(open('reporting/final/REPORT.md').read()))

# %%
# View README.md
display(Markdown(open('README.md').read()))
